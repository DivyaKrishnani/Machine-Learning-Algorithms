# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Datasets/dmf.csv")
df
# Out:
#       dmf  flor
# 0     223  2.10
# 1     232  2.80
# 2     269  1.99
# 3     261  1.46
# 4     254  1.33
# 5     320  1.30
# 6     287  1.40
# 7     330  1.18
# 8     405  0.64
# 9     451  0.59
# 10    560  0.50
# 11    639  0.46
# 12    665  0.11
# 13    713  0.31
# 14    702  0.25
# 15    684  0.26
# 16    719  0.39
# 17    780  0.27
# 18    827  0.17
# 19    832  0.25
# 20    247  2.16
# 21    239  2.75
# 22    255  1.92
# 23    217  1.32
# 24    262  1.48
# 25    310  1.31
# 26    336  1.14
# 27    404  0.77
# 28    438  0.65
# 29    537  0.66
# ...   ...   ...
# 2451  460  0.60
# 2452  584  0.48
# 2453  702  0.48
# 2454  678  0.16
# 2455  679  0.35
# 2456  717  0.20
# 2457  730  0.09
# 2458  715  0.40
# 2459  768  0.34
# 2460  799  0.25
# 2461  840  0.24
# 2462  250  2.05
# 2463  256  2.83
# 2464  249  1.96
# 2465  276  1.39
# 2466  287  1.28
# 2467  323  1.26
# 2468  311  1.51
# 2469  342  1.10
# 2470  439  0.78
# 2471  443  0.75
# 2472  583  0.59
# 2473  627  0.44
# ...

# %%
df.shape
# Out:
# (2481, 2)

# %%
df.describe()
# Out:
#                dmf         flor
# count  2481.000000  2481.000000
# mean    502.505844     0.903926
# std     212.438245     0.742189
# min     181.000000     0.000000
# 25%     289.000000     0.270000
# 50%     457.000000     0.640000
# 75%     707.000000     1.380000
# max     860.000000     2.930000

# %%
dmf = df['dmf']
dmf
# Out:
# 0       223
# 1       232
# 2       269
# 3       261
# 4       254
# 5       320
# 6       287
# 7       330
# 8       405
# 9       451
# 10      560
# 11      639
# 12      665
# 13      713
# 14      702
# 15      684
# 16      719
# 17      780
# 18      827
# 19      832
# 20      247
# 21      239
# 22      255
# 23      217
# 24      262
# 25      310
# 26      336
# 27      404
# 28      438
# 29      537
#        ...
# 2451    460
# 2452    584
# 2453    702
# 2454    678
# 2455    679
# 2456    717
# 2457    730
# 2458    715
# 2459    768
# 2460    799
# 2461    840
# 2462    250
# 2463    256
# 2464    249
# 2465    276
# 2466    287
# 2467    323
# 2468    311
# 2469    342
# 2470    439
# 2471    443
# 2472    583
# 2473    627
# 2474    701
# 2475    745
# 2476    694
# 2477    650
# 2478    727
# 2479    807
# 2480    818
# Name: dmf, Length: 2481, dtype: int64

# %%
flor = df['flor']
flor
# Out:
# 0       2.10
# 1       2.80
# 2       1.99
# 3       1.46
# 4       1.33
# 5       1.30
# 6       1.40
# 7       1.18
# 8       0.64
# 9       0.59
# 10      0.50
# 11      0.46
# 12      0.11
# 13      0.31
# 14      0.25
# 15      0.26
# 16      0.39
# 17      0.27
# 18      0.17
# 19      0.25
# 20      2.16
# 21      2.75
# 22      1.92
# 23      1.32
# 24      1.48
# 25      1.31
# 26      1.14
# 27      0.77
# 28      0.65
# 29      0.66
#         ...
# 2451    0.60
# 2452    0.48
# 2453    0.48
# 2454    0.16
# 2455    0.35
# 2456    0.20
# 2457    0.09
# 2458    0.40
# 2459    0.34
# 2460    0.25
# 2461    0.24
# 2462    2.05
# 2463    2.83
# 2464    1.96
# 2465    1.39
# 2466    1.28
# 2467    1.26
# 2468    1.51
# 2469    1.10
# 2470    0.78
# 2471    0.75
# 2472    0.59
# 2473    0.44
# 2474    0.29
# 2475    0.32
# 2476    0.25
# 2477    0.12
# 2478    0.35
# 2479    0.27
# 2480    0.17
# Name: flor, Length: 2481, dtype: float64

# %%
print(len(dmf.values))
print(dmf.values)
print(len(flor.values))
print(flor.values)
# Out:
# 2481
# [223 232 269 ..., 727 807 818]
# 2481
# [ 2.1   2.8   1.99 ...,  0.35  0.27  0.17]

# %%
Y = dmf
Y = np.array(Y).reshape(-1,1)
print(Y.shape)

X = flor
X = np.array(X).reshape(-1,1)
print(X.shape)
# Out:
# (2481, 1)
# (2481, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X,Y,test_size = 0.30, random_state=0)
print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)
# Out:
# (1736, 1)
# (1736, 1)
# (745, 1)
# (745, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
ypred = lr.predict(xtest)

# %%
import matplotlib.pyplot as plot
plot.scatter(X,Y)
plot.ylabel('dmf')
plot.xlabel('flor')
plot.show()

# %%
plot.scatter(xtrain, ytrain, color = 'red')
plot.plot(xtrain, lr.predict(xtrain), color = 'blue')
plot.title('Training Set')
plot.ylabel('dmf')
plot.xlabel('flor')
plot.show()

# %%
plot.scatter(xtest, ytest, color = 'red')
plot.plot(xtrain, lr.predict(xtrain), color = 'blue')
plot.title('Test Set')
plot.ylabel('dmf')
plot.xlabel('flor')
plot.show()

# %%
#Coeffients and Intercept
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[-255.21337021]]
# [ 733.12043176]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
y_train_predict = lr.predict(xtrain)
rmse = (np.sqrt(mean_squared_error(ytrain, y_train_predict)))
r2 = r2_score(ytrain, y_train_predict)

# %%
print(r2)
print(rmse)
# Out:
# 0.7842110137
# 99.1977134144

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
model.summary()
# Out:
# /home/divya/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     8760.
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):               0.00
# Time:                        15:45:53   Log-Likelihood:                -14940.
# No. Observations:                2481   AIC:                         2.988e+04
# Df Residuals:                    2479   BIC:                         2.989e+04
# Df Model:                           1
# ...

# %%
# model evaluation for training set
y_train_predict = lr.predict(xtrain)
rmse = (np.sqrt(mean_squared_error(ytrain, y_train_predict)))
r2 = r2_score(ytrain, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lr.predict(xtest)
rmse = (np.sqrt(mean_squared_error(ytest, y_test_predict)))
r2 = r2_score(ytest, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 99.19771341440439
# R2 score is 0.7842110136997591
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 101.08490991934623
# R2 score is 0.7676161691804692

# %%
#SSE
y_test_predict = lr.predict(xtest)
sse = mean_squared_error(ytest, y_test_predict)
sse
# Out:
# 10218.159013402343

# %%
a = (ytest - y_test_predict)**2
print(a)
# Out:
# [[  1.10442152e+03]
#  [  3.73527015e+04]
#  [  9.58273512e+03]
#  [  1.21850082e+04]
#  [  7.21903701e+03]
#  [  1.22413035e+03]
#  [  3.39370280e+03]
#  [  2.86488829e+02]
#  [  1.94687296e+02]
#  [  9.69720273e+03]
#  [  4.27480409e+03]
#  [  4.70888521e+03]
#  [  3.41166727e+03]
#  [  5.98671223e+03]
#  [  1.03033001e+04]
#  [  4.61086127e+03]
#  [  4.20002885e+03]
#  [  1.13655727e+04]
#  [  1.64749875e+04]
#  [  6.26188932e+04]
#  [  9.74374388e+03]
#  [  9.29542465e+03]
#  [  9.88976904e+03]
#  [  5.77462408e+01]
#  [  7.47249240e+03]
#  [  1.83675207e+03]
#  [  8.30481853e+03]
#  [  3.03204999e+02]
#  [  4.15428385e+04]
#  [  3.04413079e+04]
#  [  1.98590784e+04]
#  [  4.53501164e+04]
#  [  3.74426078e+02]
#  [  5.86285863e+04]
#  [  8.33013619e+03]
#  [  1.48134225e+04]
#  [  2.92259658e+03]
#  [  2.44093891e+04]
#  [  4.84415643e+00]
#  [  1.07558479e+04]
#  [  1.97341007e+04]
#  [  1.38420200e+04]
#  [  1.65245489e+04]
#  [  1.28457996e+04]
#  [  4.35137019e+03]
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(a, bins='auto') 
plt.show()

# %%
plot.scatter(xtest,ypred, color = 'red')
plot.scatter(xtest, ytest, color = 'blue')
plot.title('Predicted Vs Actual')
plot.ylabel('dmf')
plot.xlabel('flor')
plot.show()

# %%
plot.scatter(xtest,a, color = 'red')
plot.scatter(xtest, ypred, color = 'blue')
plot.title('Predicted Vs Error')
plot.ylabel('dmf')
plot.xlabel('flor')
plot.show()

# %%
dmf = df['dmf']
flor = df['flor'] + df['flor']**2

Y = dmf
Y = np.array(Y).reshape(-1,1)
print(Y.shape)

X = flor
X = np.array(X).reshape(-1,1)
print(X.shape)

xtrain, xtest, ytrain, ytest = train_test_split(X,Y,test_size = 0.30, random_state=0)
print(xtrain.shape)
print(ytrain.shape)
print(xtest.shape)
print(ytest.shape)

lr = LinearRegression()
lr.fit(xtrain,ytrain)
ypred = lr.predict(xtest)
# Out:
# (2481, 1)
# (2481, 1)
# (1736, 1)
# (1736, 1)
# (745, 1)
# (745, 1)

# %%
import matplotlib.pyplot as plot
plot.scatter(X,Y)
plot.ylabel('dmf')
plot.xlabel('flor + flor**2')
plot.show()

# %%
plot.scatter(xtrain, ytrain, color = 'red')
plot.plot(xtrain, lr.predict(xtrain), color = 'blue')
plot.title('Training Set')
plot.ylabel('dmf')
plot.xlabel('flor + flor**2')
plot.show()

# %%
plot.scatter(xtest, ytest, color = 'red')
plot.plot(xtrain, lr.predict(xtrain), color = 'blue')
plot.title('Test Set')
plot.ylabel('dmf')
plot.xlabel('flor+flor**2')
plot.show()

# %%
#Coeffients and Intercept
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[-63.3712292]]
# [ 646.19939109]

# %%
y_train_predict = lr.predict(xtrain)
rmse = (np.sqrt(mean_squared_error(ytrain, y_train_predict)))
r2 = r2_score(ytrain, y_train_predict)

# %%
print(r2)
print(rmse)
# Out:
# 0.610289563175
# 133.308561596

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     3816.
# Date:                Tue, 12 Feb 2019   Prob (F-statistic):               0.00
# Time:                        15:51:21   Log-Likelihood:                -15659.
# No. Observations:                2481   AIC:                         3.132e+04
# Df Residuals:                    2479   BIC:                         3.133e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        644.4662      3.528    182.659      0.000     637.548     651.385
# ...

# %%
# model evaluation for training set
y_train_predict = lr.predict(xtrain)
rmse = (np.sqrt(mean_squared_error(ytrain, y_train_predict)))
r2 = r2_score(ytrain, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lr.predict(xtest)
rmse = (np.sqrt(mean_squared_error(ytest, y_test_predict)))
r2 = r2_score(ytest, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 133.3085615959329
# R2 score is 0.6102895631747418
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 133.31845859573335
# R2 score is 0.5957837046259793

# %%
#SSE
y_test_predict = lr.predict(xtest)
sse = mean_squared_error(ytest, y_test_predict)
sse
# Out:
# 17773.811402342268

# %%
a = (ytest - y_test_predict)**2
print(a)
# Out:
# [[  2.57904330e+02]
#  [  5.44951100e+04]
#  [  1.80923444e+04]
#  [  2.49045805e+04]
#  [  1.10856677e+04]
#  [  8.67134374e+03]
#  [  2.41712753e+02]
#  [  5.48531699e+03]
#  [  6.48640746e+03]
#  [  2.18753679e+04]
#  [  5.59796209e+03]
#  [  7.18554224e+03]
#  [  2.92797560e+03]
#  [  1.81370406e+04]
#  [  2.76615780e+04]
#  [  4.20863631e+03]
#  [  1.17310975e+02]
#  [  2.81953321e+04]
#  [  2.90871179e+04]
#  [  9.31112870e+04]
#  [  1.44059173e+04]
#  [  1.39604037e+04]
#  [  2.37951590e+04]
#  [  3.69316842e+03]
#  [  1.47659896e+04]
#  [  1.58496838e+03]
#  [  1.84036049e+04]
#  [  1.53304764e+03]
#  [  6.03095454e+04]
#  [  5.01326601e+04]
#  [  3.68677264e+04]
#  [  5.94770587e+04]
#  [  4.15002223e+03]
#  [  8.62450204e+04]
#  [  2.21585902e+04]
#  [  2.04560513e+04]
#  [  1.25603796e+04]
#  [  3.90303580e+04]
#  [  8.05586320e+00]
#  [  1.56311638e+04]
#  [  3.89822957e+04]
#  [  2.15128343e+04]
#  [  2.57822805e+04]
#  [  2.29561460e+04]
#  [  7.44570476e+03]
# ...

# %%
plt.hist(a, bins='auto') 
plt.show()

# %%
plot.scatter(xtest,ypred, color = 'red')
plot.scatter(xtest, ytest, color = 'blue')
plot.title('Predicted Vs Actual')
plot.ylabel('dmf')
plot.xlabel('flor+flor**2')
plot.show()

# %%
plot.scatter(xtest,a, color = 'red')
plot.scatter(xtest, ypred, color = 'blue')
plot.title('Predicted Vs Error')
plot.ylabel('dmf')
plot.xlabel('flor+flor**2')
plot.show()
